# %%
# %load_ext tensorboard

# %%
# %%capture
# !pip install datasets
# !pip install tokenizers
# !pip install torchmetrics

# %%
# %%capture
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/dannychemm123/transformer_scratch.git
# Out:
# fatal: destination path 'transformer_scratch' already exists and is not an empty directory.

# %%
# %%capture
# %cd /content/transformer_scratch

# %%
# %tensorboard --logdir runs

# %%
import os

weights_path = "/content/drive/MyDrive/Models/transformer_scratch/weights"
vocab_path = "/content/drive/MyDrive/Models/transformer_scratch/vocab"

os.makedirs(weights_path, exist_ok=True)
os.makedirs(vocab_path, exist_ok=True)

# %%
from small_training.small_config import get_config
cfg = get_config()
cfg['model_folder'] = '..//drive/MyDrive/Models/transformer_scratch/weights'
cfg['tokenizer_file'] = '..//drive/MyDrive/Models/transformer_scratch/vocab/tokenizer_{0}.json'
cfg['batch_size'] = 8
cfg['num_epochs'] = 2
cfg['seq_len'] = 350
cfg['preload'] = None
from train import train_model

train_model(cfg)
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Max len src: 309
# Max len tgt: 274
# Processing epoch 00:  32%|███▏      | 1166/3638 [05:56<12:36,  3.27batch/s, loss=6.552]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...

# %%
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

print(torch.cuda.memory_allocated() / 1024**3, "GB allocated")
print(torch.cuda.memory_reserved() / 1024**3, "GB reserved")
# Out:
# 0.0 GB allocated
# 0.0 GB reserved
